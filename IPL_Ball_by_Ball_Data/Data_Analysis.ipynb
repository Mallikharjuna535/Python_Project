# %% [markdown]
# #### Install all neccessary files

# %%
#Numpy is an fundamental python library working with arrays, matrices, and various mathematical functions.
import numpy as np

# %%
#Pandas is a Python library used for working with data sets.
#For analyzing, cleaning, exploring, and manipulating data.
import pandas as pd

# %%
#Opening Matches CSV file using Pandas
#To open any CSV file we use pandas library 
df = pd.read_csv('matches.csv')

#head is used to display top rows in the file, where by default it will display top 5
df.head()
# Out:
#        id   season        city       date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  4/18/2008     League     BB McCullum
# 1  335983  2007/08  Chandigarh  4/19/2008     League      MEK Hussey
# 2  335984  2007/08       Delhi  4/19/2008     League     MF Maharoof
# 3  335985  2007/08      Mumbai  4/20/2008     League      MV Boucher
# 4  335986  2007/08     Kolkata  4/20/2008     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# ...

# %%
#tail is used to display the bottom rows of the CSV file, by default it will display bottom 5
df.tail()
# Out:
#            id season       city       date   match_type  player_of_match  \
# 1090  1426307   2024  Hyderabad  5/19/2024       League  Abhishek Sharma
# 1091  1426309   2024  Ahmedabad  5/21/2024  Qualifier 1         MA Starc
# 1092  1426310   2024  Ahmedabad  5/22/2024   Eliminator         R Ashwin
# 1093  1426311   2024    Chennai  5/24/2024  Qualifier 2    Shahbaz Ahmed
# 1094  1426312   2024    Chennai  5/26/2024        Final         MA Starc
#
#                                                   venue  \
# 1090  Rajiv Gandhi International Stadium, Uppal, Hyd...
# 1091                   Narendra Modi Stadium, Ahmedabad
# 1092                   Narendra Modi Stadium, Ahmedabad
# 1093           MA Chidambaram Stadium, Chepauk, Chennai
# 1094           MA Chidambaram Stadium, Chepauk, Chennai
#
#                             team1                  team2          toss_winner  \
# 1090                 Punjab Kings    Sunrisers Hyderabad         Punjab Kings
# ...

# %%
#Info is used to display the all the column names and count of the data in it with their datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               1095 non-null   int64
#  1   season           1095 non-null   object
#  2   city             1044 non-null   object
#  3   date             1095 non-null   object
#  4   match_type       1095 non-null   object
#  5   player_of_match  1090 non-null   object
#  6   venue            1095 non-null   object
#  7   team1            1095 non-null   object
#  8   team2            1095 non-null   object
#  9   toss_winner      1095 non-null   object
#  10  toss_decision    1095 non-null   object
#  11  winner           1090 non-null   object
#  12  result           1095 non-null   object
#  13  result_margin    1076 non-null   float64
#  14  target_runs      1092 non-null   float64
#  15  target_overs     1092 non-null   float64
# ...

# %%
def fibbonoci(n):
    if n == 0:
        return 0
    else:
        return n + fibbonoci(n-1)
    
print(fibbonoci(5))
# Out:
# 15

# %%
print("Hello World")
# Out:
# Hello World
